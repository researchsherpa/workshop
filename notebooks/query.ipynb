# %% [markdown]
# #  Scratch pad to explore queries.
#
# I'm demonstrating possible queries on the dataframes.  I'm going to stick to the non-spatial ones for starters.<br/>
#
# What you should be thinking about is how queries such as this can be used to pick subsets of information that can be plotted, mapped, ...

# %%
import pandas as pd
import geopandas as gpd

# %%
ecb_gdf = gpd.read_file("../data/ecb.shp")

# %%
ecb_gdf.columns
# Out:
# Index(['BUSINESS A', 'DBA NAME', 'OWNERSHIP', 'ADDRESS', 'CITY', 'ZIP',
#        'STATE', 'BUSINESS P', 'OWNER NAME', 'CREATION D', 'START DT', 'EXP DT',
#        'NAICS', 'ACTIVITY D', 'today', 'years', 'naics_code', 'NAICS Desc',
#        'sector', 'sector_des', 'zip_code', 'geometry'],
#       dtype='object')

# %%
biz_df = pd.read_csv('../data/transformed.csv', sep='\t').reset_index()
#biz_df['sector'] = biz_df['sector'].astype(str)

# %%
biz_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53675 entries, 0 to 53674
# Data columns (total 23 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              53675 non-null  int64
#  1   Unnamed: 0         53675 non-null  int64
#  2   BUSINESS ACCT#     53675 non-null  int64
#  3   DBA NAME           53675 non-null  object
#  4   OWNERSHIP TYPE     53675 non-null  object
#  5   ADDRESS            53675 non-null  object
#  6   CITY               53647 non-null  object
#  7   ZIP                53675 non-null  object
#  8   STATE              53675 non-null  object
#  9   BUSINESS PHONE     48269 non-null  object
#  10  OWNER NAME         53675 non-null  object
#  11  CREATION DT        53675 non-null  object
#  12  START DT           53675 non-null  object
#  13  EXP DT             53675 non-null  object
#  14  NAICS              53675 non-null  int64
#  15  ACTIVITY DESC      53675 non-null  object
#  16  today              53675 non-null  object
#  17  years              53675 non-null  int64
#  18  naics_code         53675 non-null  int64
#  19  NAICS Description  53675 non-null  object
#  20  sector             53675 non-null  int64
#  21  sector_desc        53675 non-null  object
#  22  zip_code           53675 non-null  object
# dtypes: int64(7), object(16)
# memory usage: 9.4+ MB

# %% [markdown]
# ## Note to self
#
# I think of NAICS codes not as integers but character strings (of digits). <br/>
# When I created transformed.csv in wrangling I did such a conversion. Writing and reading has converted it back to int64 so ...<br/>
# My initial discussion with `the goog` indicates that is a `feature` of csv, not pandas?<br/>
# I wonder if this could be a variant of the famous SettingWithCopy warning?!?!

# %% [markdown]
# In the mean time.

# %%
biz_df['sector'] = biz_df['sector'].astype(str)

# %% [markdown]
# ## Looking at some queries
#
# These are meant to be examples.  Pandas provides several techniques to filter rows.  I like using query.<br/>
#
# I am going to look at examples from my neighborhood (the peninsula).

# %%
# 92110 is the northern part of peninsula but it also covers bay park and midway.
# Kind of skews things but ...
zips = ['92106', '92107', '92110']

# %%
len(biz_df.query(f"zip_code in @zips"))
# Out:
# 3971

# %%
biz_df.query(f"zip_code in @zips and years >= 5")
# Out:
#        index  Unnamed: 0  BUSINESS ACCT#  \
# 28        28          29      1993003503
# 33        33          34      2007015912
# 36        36          37      2007016590
# 88        88          89      2007000179
# 89        89          90      1997014273
# ...      ...         ...             ...
# 53568  53568       53569      1987013586
# 53594  53594       53595      1989008612
# 53604  53604       53605      1985008562
# 53641  53641       53642      2004007859
# 53642  53642       53643      2010027498
#
#                                      DBA NAME OWNERSHIP TYPE  \
# 28                              1127 OPAL INC          SCORP
# 33                      1344 HOLLY AVENUE LLC            LLC
# 36                      1430 UNION STREET LLC            LLC
# 88                              220 GROUP LLC            LLC
# 89             2250 FOURTH AVENUE PARTNERSHIP         PARTNR
# ...                                       ...            ...
# 53568                  ZEUGSCHMIDT MOTOR CARS           SOLE
# 53594  ZIGMAN/SHIELDS GENERAL CONTRACTORS INC           CORP
# 53604                    ZINO'S INTERNATIONAL           SOLE
# 53641              ZOOK FAMILY INVESTMENTS LP             LP
# 53642                   ZOOKS EARL SCHEIB INC           CORP
#
#                              ADDRESS       CITY         ZIP STATE  \
# 28                  3518 BARNETT AVE  SAN DIEGO  92110-3208    CA
# 33     4817 SANTA MONICA AVE SUITE A  SAN DIEGO  92107-2850    CA
# 36                     575 ALBION ST  SAN DIEGO  92106-3209    CA
# 88          3405 KENYON ST SUITE 301  SAN DIEGO  92110-5007    CA
# 89     2251 SAN DIEGO AVE SUITE A120  SAN DIEGO  92110-2969    CA
# ...                              ...        ...         ...   ...
# 53568              3256 ROSECRANS ST  SAN DIEGO  92110-4837    CA
# 53594    3276 ROSECRANS ST SUITE 300  SAN DIEGO  92110-4838    CA
# 53604           2168 CHATSWORTH BLVD  SAN DIEGO  92107-2423    CA
# 53641                  4533 ADAIR ST  SAN DIEGO  92107-3803    CA
# 53642              3820 ROSECRANS ST  SAN DIEGO  92110-3114    CA
#
#        BUSINESS PHONE  ...      EXP DT   NAICS  \
# 28     (619) 985-0665  ...   4/30/2021     421
# 33                NaN  ...   6/30/2021     541
# 36                NaN  ...   6/30/2021     541
# 88     (619) 758-9696  ...   7/31/2021  541512
# 89     (619) 685-4249  ...  12/31/2020    5311
# ...               ...  ...         ...     ...
# 53568  (619) 222-4342  ...  10/31/2021   44112
# 53594  (619) 294-8754  ...   7/31/2021     233
# 53604  (619) 574-7895  ...  10/31/2021  812112
# 53641  (619) 226-7610  ...   5/31/2021   53111
# 53642  (619) 291-3004  ...   8/31/2021   81112
#
#                                        ACTIVITY DESC       today  years  \
# 28                    WHOLESALE TRADE, DURABLE GOODS  12/22/2020     28
# 33     PROFESSIONAL, SCIENTIFIC & TECHNICAL SERVICES  12/22/2020     13
# 36     PROFESSIONAL, SCIENTIFIC & TECHNICAL SERVICES  12/22/2020     13
# 88                  COMPUTER SYSTEMS DESIGN SERVICES  12/22/2020     14
# 89                            LESSORS OF REAL ESTATE  12/22/2020     23
# ...                                              ...         ...    ...
# 53568                               USED CAR DEALERS  12/22/2020     33
# 53594     BUILDING, DEVELOPING & GENERAL CONTRACTING  12/22/2020     31
# 53604                                  BEAUTY SALONS  12/22/2020     36
# 53641   LESSORS OF RESIDENTIAL BUILDINGS & DWELLINGS  12/22/2020     17
# 53642  AUTOMOTIVE BODY/PAINT/INTERIOR & GLASS REPAIR  12/22/2020     10
#
#       naics_code                                  NAICS Description  sector  \
# 28           421                     WHOLESALE TRADE, DURABLE GOODS      42
# 33           541  Professional, Scientific, and Technical Servic...      54
# 36           541  Professional, Scientific, and Technical Servic...      54
# 88          5415     Computer Systems Design and Related ServicesT       54
# 89          5311                           Lessors of Real EstateT       53
# ...          ...                                                ...     ...
# 53568       4411                                Automobile Dealers       44
# 53594        233         BUILDING, DEVELOPING & GENERAL CONTRACTING      23
# 53604       8121                            Personal Care Services       81
# 53641       5311                           Lessors of Real EstateT       53
# 53642       8111                Automotive Repair and MaintenanceT       81
#
#                                              sector_desc zip_code
# 28                                   Wholesale Trade(42)    92110
# 33     Professional, Scientific, and Technical Servic...    92107
# 36     Professional, Scientific, and Technical Servic...    92106
# 88     Professional, Scientific, and Technical Servic...    92110
# 89                Real Estate and Rental and Leasing(53)    92110
# ...                                                  ...      ...
# 53568                                   Retail Trade(44)    92110
# 53594                                   Construction(23)    92110
# 53604  Other Services (except Public Administration)(81)    92107
# 53641             Real Estate and Rental and Leasing(53)    92107
# 53642  Other Services (except Public Administration)(81)    92110
#
# [2690 rows x 23 columns]

# %%
print(f"{len(_)/__:.2%}")
# Out:
# 67.74%

# %% [markdown]
# ### Interesting - 68% of the businesses have been around more than 5 years.

# %% [markdown]
# ### A few more hacky examples.

# %%
biz_df.query(f"zip_code == '92110' and sector == '54'")
# Out:
#        index  Unnamed: 0  BUSINESS ACCT#                         DBA NAME  \
# 88        88          89      2007000179                    220 GROUP LLC
# 147      147         148      2007007100                         3515 LTD
# 184      184         185      2020015969       4 STAR MGMT CONSULTING INC
# 217      217         218      2007018866                         4891 LTD
# 360      360         361      2009007812            718 VENTURA PLACE LLC
# ...      ...         ...             ...                              ...
# 52897  52897       52898      2019004283                 WOOD RODGERS INC
# 53035  53035       53036      2004009789                   WSA LUMBER INC
# 53475  53475       53476      2019009791       ZACHARY BARRON PHOTOGRAPHY
# 53496  53496       53497      2002003117  ZAMORA FINANCIAL CONSULTING INC
# 53623  53623       53624      2018004678                              ZJR
#
#       OWNERSHIP TYPE                       ADDRESS       CITY         ZIP  \
# 88               LLC      3405 KENYON ST SUITE 301  SAN DIEGO  92110-5007
# 147               LP              4895 SAVANNAH ST  SAN DIEGO  92110-3824
# 184             CORP               2019 CHICAGO ST  SAN DIEGO  92110-3421
# 217             CORP              4895 SAVANNAH ST  SAN DIEGO  92110-3824
# 360              LLC                5145 MORENA PL  SAN DIEGO  92110-3921
# ...              ...                           ...        ...         ...
# 52897          SCORP     1775 HANCOCK ST SUITE 160  SAN DIEGO  92110-2039
# 53035           CORP                 5328 METRO ST  SAN DIEGO  92110-2608
# 53475          SCORP                 5343 BANKS ST  SAN DIEGO  92110-4008
# 53496           CORP  3990 OLD TOWN AVE SUITE 109A  SAN DIEGO  92110-2974
# 53623           CORP              2076 GARFIELD RD  SAN DIEGO  92110-1229
#
#       STATE  BUSINESS PHONE  ...      EXP DT   NAICS  \
# 88       CA  (619) 758-9696  ...   7/31/2021  541512
# 147      CA  (619) 276-2532  ...   5/31/2021     541
# 184      CA  (708) 209-6456  ...   5/31/2021  541615
# 217      CA             NaN  ...   6/30/2021     541
# 360      CA             NaN  ...   3/31/2021     541
# ...     ...             ...  ...         ...     ...
# 52897    CA  (619) 819-9240  ...  12/31/2020   54133
# 53035    CA             NaN  ...   3/31/2021      54
# 53475    CA  (619) 543-9959  ...   4/30/2021  541922
# 53496    CA  (619) 501-6778  ...   2/28/2021   54161
# 53623    CA  (619) 248-4601  ...   2/28/2021  541615
#
#                                        ACTIVITY DESC       today  years  \
# 88                  COMPUTER SYSTEMS DESIGN SERVICES  12/22/2020     14
# 147    PROFESSIONAL, SCIENTIFIC & TECHNICAL SERVICES  12/22/2020     14
# 184                              CONSULTING SERVICES  12/22/2020      0
# 217    PROFESSIONAL, SCIENTIFIC & TECHNICAL SERVICES  12/22/2020     13
# 360    PROFESSIONAL, SCIENTIFIC & TECHNICAL SERVICES  12/22/2020     12
# ...                                              ...         ...    ...
# 52897                           ENGINEERING SERVICES  12/22/2020      2
# 53035  PROFESSIONAL, SCIENTIFIC & TECHNICAL SERVICES  12/22/2020     16
# 53475                         COMMERCIAL PHOTOGRAPHY  12/22/2020      2
# 53496                 MANAGEMENT CONSULTING SERVICES  12/22/2020     19
# 53623                            CONSULTING SERVICES  12/22/2020      3
#
#       naics_code                                  NAICS Description  sector  \
# 88          5415     Computer Systems Design and Related ServicesT       54
# 147          541  Professional, Scientific, and Technical Servic...      54
# 184         5416  Management, Scientific, and Technical Consulti...      54
# 217          541  Professional, Scientific, and Technical Servic...      54
# 360          541  Professional, Scientific, and Technical Servic...      54
# ...          ...                                                ...     ...
# 52897       5413  Architectural, Engineering, and Related Servic...      54
# 53035         54  Professional, Scientific, and Technical ServicesT      54
# 53475       5419  Other Professional, Scientific, and Technical ...      54
# 53496       5416  Management, Scientific, and Technical Consulti...      54
# 53623       5416  Management, Scientific, and Technical Consulti...      54
#
#                                              sector_desc zip_code
# 88     Professional, Scientific, and Technical Servic...    92110
# 147    Professional, Scientific, and Technical Servic...    92110
# 184    Professional, Scientific, and Technical Servic...    92110
# 217    Professional, Scientific, and Technical Servic...    92110
# 360    Professional, Scientific, and Technical Servic...    92110
# ...                                                  ...      ...
# 52897  Professional, Scientific, and Technical Servic...    92110
# 53035  Professional, Scientific, and Technical Servic...    92110
# 53475  Professional, Scientific, and Technical Servic...    92110
# 53496  Professional, Scientific, and Technical Servic...    92110
# 53623  Professional, Scientific, and Technical Servic...    92110
#
# [329 rows x 23 columns]

# %%
biz_df.query(f"zip_code == '92110' and years >= 5 and sector == '54'")
# Out:
#        index  Unnamed: 0  BUSINESS ACCT#                         DBA NAME  \
# 88        88          89      2007000179                    220 GROUP LLC
# 147      147         148      2007007100                         3515 LTD
# 217      217         218      2007018866                         4891 LTD
# 360      360         361      2009007812            718 VENTURA PLACE LLC
# 768      768         769      1998011190       AAA COLEMAN MOVING SYSTEMS
# ...      ...         ...             ...                              ...
# 52683  52683       52684      2004015488                  WILLIAM P CHUTE
# 52862  52862       52863      1985004299            WOLF DESIGN BUILD INC
# 52882  52882       52883      2015044333                 WONDERIST AGENCY
# 53035  53035       53036      2004009789                   WSA LUMBER INC
# 53496  53496       53497      2002003117  ZAMORA FINANCIAL CONSULTING INC
#
#       OWNERSHIP TYPE                        ADDRESS       CITY         ZIP  \
# 88               LLC       3405 KENYON ST SUITE 301  SAN DIEGO  92110-5007
# 147               LP               4895 SAVANNAH ST  SAN DIEGO  92110-3824
# 217             CORP               4895 SAVANNAH ST  SAN DIEGO  92110-3824
# 360              LLC                 5145 MORENA PL  SAN DIEGO  92110-3921
# 768             CORP    3045 ROSECRANS ST SUITE 202  SAN DIEGO  92110-4818
# ...              ...                            ...        ...         ...
# 52683           SOLE             3930 CALIFORNIA ST  SAN DIEGO  92110-2117
# 52862           CORP                  1459 LIETA ST  SAN DIEGO  92110-3632
# 52882         PARTNR  3015 SAINT CHARLES ST SUITE B  SAN DIEGO  92110-4857
# 53035           CORP                  5328 METRO ST  SAN DIEGO  92110-2608
# 53496           CORP   3990 OLD TOWN AVE SUITE 109A  SAN DIEGO  92110-2974
#
#       STATE  BUSINESS PHONE  ...      EXP DT   NAICS  \
# 88       CA  (619) 758-9696  ...   7/31/2021  541512
# 147      CA  (619) 276-2532  ...   5/31/2021     541
# 217      CA             NaN  ...   6/30/2021     541
# 360      CA             NaN  ...   3/31/2021     541
# 768      CA             NaN  ...  10/31/2021   54199
# ...     ...             ...  ...         ...     ...
# 52683    CA  (619) 298-9614  ...  12/31/2020   54161
# 52862    CA  (619) 275-0074  ...   2/28/2021   54133
# 52882    CA  (262) 844-1628  ...   9/30/2021    5418
# 53035    CA             NaN  ...   3/31/2021      54
# 53496    CA  (619) 501-6778  ...   2/28/2021   54161
#
#                                        ACTIVITY DESC       today  years  \
# 88                  COMPUTER SYSTEMS DESIGN SERVICES  12/22/2020     14
# 147    PROFESSIONAL, SCIENTIFIC & TECHNICAL SERVICES  12/22/2020     14
# 217    PROFESSIONAL, SCIENTIFIC & TECHNICAL SERVICES  12/22/2020     13
# 360    PROFESSIONAL, SCIENTIFIC & TECHNICAL SERVICES  12/22/2020     12
# 768    ALL OTH PROF, SCIENTIFIC & TECHNICAL SERVICES  12/22/2020     22
# ...                                              ...         ...    ...
# 52683                 MANAGEMENT CONSULTING SERVICES  12/22/2020     16
# 52862                           ENGINEERING SERVICES  12/22/2020     36
# 52882                 ADVERTISING & RELATED SERVICES  12/22/2020      5
# 53035  PROFESSIONAL, SCIENTIFIC & TECHNICAL SERVICES  12/22/2020     16
# 53496                 MANAGEMENT CONSULTING SERVICES  12/22/2020     19
#
#       naics_code                                  NAICS Description  sector  \
# 88          5415     Computer Systems Design and Related ServicesT       54
# 147          541  Professional, Scientific, and Technical Servic...      54
# 217          541  Professional, Scientific, and Technical Servic...      54
# 360          541  Professional, Scientific, and Technical Servic...      54
# 768         5419  Other Professional, Scientific, and Technical ...      54
# ...          ...                                                ...     ...
# 52683       5416  Management, Scientific, and Technical Consulti...      54
# 52862       5413  Architectural, Engineering, and Related Servic...      54
# 52882       5418  Advertising, Public Relations, and Related Ser...      54
# 53035         54  Professional, Scientific, and Technical ServicesT      54
# 53496       5416  Management, Scientific, and Technical Consulti...      54
#
#                                              sector_desc zip_code
# 88     Professional, Scientific, and Technical Servic...    92110
# 147    Professional, Scientific, and Technical Servic...    92110
# 217    Professional, Scientific, and Technical Servic...    92110
# 360    Professional, Scientific, and Technical Servic...    92110
# 768    Professional, Scientific, and Technical Servic...    92110
# ...                                                  ...      ...
# 52683  Professional, Scientific, and Technical Servic...    92110
# 52862  Professional, Scientific, and Technical Servic...    92110
# 52882  Professional, Scientific, and Technical Servic...    92110
# 53035  Professional, Scientific, and Technical Servic...    92110
# 53496  Professional, Scientific, and Technical Servic...    92110
#
# [259 rows x 23 columns]

# %%
print(f"{len(_)/len(__):.2%} consulting business longer than 5 years")
# Out:
# 78.72% consulting business longer than 5 years

# %% [markdown]
# ### Once again not bad!

# %%
biz_df.query(f"sector == '54'")['zip_code'].value_counts()
# Out:
# 92101        1051
# 92121         620
# 92130         568
# 92108         561
# 92037         504
#              ...
# 90016           1
# 921302666       1
# 90630           1
# 77406           1
# 45231           1
# Name: zip_code, Length: 373, dtype: int64

# %% [markdown]
# Yo -- do you see the broken zip code?

# %% [markdown]
# ## Businesses open 25 years in the peninsula

# %%
biz_df.query(f"years == 25 and zip_code in @zips")['sector_desc'].value_counts()
# Out:
# Professional, Scientific, and Technical Services(54)                            23
# Other Services (except Public Administration)(81)                               16
# Retail Trade(45)                                                                 6
# Construction(23)                                                                 5
# Administrative and Support and Waste Management and Remediation Services(56)     3
# Retail Trade(44)                                                                 3
# Health Care and Social Assistance(62)                                            2
# Arts, Entertainment, and Recreation(71)                                          2
# Educational Services(61)                                                         2
# Real Estate and Rental and Leasing(53)                                           2
# Transportation and Warehousing(48)                                               1
# Manufacturing(33)                                                                1
# Finance and Insurance(52)                                                        1
# Manufacturing(32)                                                                1
# Wholesale Trade(42)                                                              1
# Accommodation and Food Services(72)                                              1
# Name: sector_desc, dtype: int64

# %%
sum(_)
# Out:
# 70

# %%
biz_df.query(f"years <= 5 and zip_code in @zips")['sector_desc'].value_counts()
# Out:
# Other Services (except Public Administration)(81)                               267
# Professional, Scientific, and Technical Services(54)                            235
# Retail Trade(45)                                                                166
# Accommodation and Food Services(72)                                             140
# Administrative and Support and Waste Management and Remediation Services(56)     89
# Real Estate and Rental and Leasing(53)                                           87
# Health Care and Social Assistance(62)                                            79
# Educational Services(61)                                                         76
# Arts, Entertainment, and Recreation(71)                                          75
# Retail Trade(44)                                                                 73
# Construction(23)                                                                 45
# Transportation and Warehousing(48)                                               40
# Wholesale Trade(42)                                                              24
# Information(51)                                                                  19
# Manufacturing(33)                                                                18
# Finance and Insurance(52)                                                        16
# Manufacturing(31)                                                                 9
# Transportation and Warehousing(49)                                                6
# Agriculture, Forestry, Fishing and Hunting(11)                                    4
# Management of Companies and EnterprisesT(55)                                      2
# Manufacturing(32)                                                                 2
# Utilities(22)                                                                     1
# Name: sector_desc, dtype: int64

# %%
sum(_)
# Out:
# 1473

# %% [markdown]
# ### So 1473 businesses are less than 5 years old.

# %% [markdown]
# ## Going to stop here.  You should get the gist of how you can interact with the data.
